# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('spy.csv')
print(df.head())
# Out:
#          Date  Year  Month  Day    Weekday  Week_Number Year_Week    Open  \
# 0  2014-01-02  2014      1    2   Thursday            0   2014-00  183.98
# 1  2014-01-03  2014      1    3     Friday            0   2014-00  183.23
# 2  2014-01-06  2014      1    6     Monday            1   2014-01  183.49
# 3  2014-01-07  2014      1    7    Tuesday            1   2014-01  183.09
# 4  2014-01-08  2014      1    8  Wednesday            1   2014-01  183.45
#
#      High     Low   Close       Volume  Adj Close    Return    Short_MA  \
# 0  184.07  182.48  182.92  119636900.0     160.93  0.000000  160.930000
# 1  183.60  182.63  182.89   81390600.0     160.90 -0.000164  160.915000
# 2  183.56  182.08  182.36  108028200.0     160.43 -0.002898  160.753333
# 3  183.79  182.95  183.48   86144200.0     161.42  0.006142  160.920000
# 4  183.83  182.89  183.52   96582300.0     161.45  0.000218  161.026000
#
#       Long_MA
# 0  160.930000
# 1  160.915000
# 2  160.753333
# 3  160.920000
# ...

# %%
df[["Year", "Weekday"]]
# Out:
#       Year    Weekday
# 0     2014   Thursday
# 1     2014     Friday
# 2     2014     Monday
# 3     2014    Tuesday
# 4     2014  Wednesday
# ...    ...        ...
# 1505  2019    Tuesday
# 1506  2019   Thursday
# 1507  2019     Friday
# 1508  2019     Monday
# 1509  2019    Tuesday
#
# [1510 rows x 2 columns]

# %%
df["high_low_diff"] = df["High"] - df["Low"]
df
# Out:
#             Date  Year  Month  Day    Weekday  Week_Number Year_Week    Open  \
# 0     2014-01-02  2014      1    2   Thursday            0   2014-00  183.98
# 1     2014-01-03  2014      1    3     Friday            0   2014-00  183.23
# 2     2014-01-06  2014      1    6     Monday            1   2014-01  183.49
# 3     2014-01-07  2014      1    7    Tuesday            1   2014-01  183.09
# 4     2014-01-08  2014      1    8  Wednesday            1   2014-01  183.45
# ...          ...   ...    ...  ...        ...          ...       ...     ...
# 1505  2019-12-24  2019     12   24    Tuesday           51   2019-51  321.47
# 1506  2019-12-26  2019     12   26   Thursday           51   2019-51  321.65
# 1507  2019-12-27  2019     12   27     Friday           51   2019-51  323.74
# 1508  2019-12-30  2019     12   30     Monday           52   2019-52  322.95
# 1509  2019-12-31  2019     12   31    Tuesday           52   2019-52  320.53
#
# ...

# %%
df_2 = df.sort_values(by=["Volume"], ascending=False)
df_2[["Date", "Volume"]]
# Out:
#             Date       Volume
# 413   2015-08-24  507244300.0
# 198   2014-10-15  380715000.0
# 414   2015-08-25  369833100.0
# 1031  2018-02-06  355026800.0
# 412   2015-08-21  346588500.0
# ...          ...          ...
# 905   2017-08-07   31995000.0
# 955   2017-10-17   31561000.0
# 1506  2019-12-26   30911200.0
# 982   2017-11-24   27856500.0
# 1505  2019-12-24   20270000.0
#
# [1510 rows x 2 columns]

# %%
df.head()
# Out:
#          Date  Year  Month  Day    Weekday  Week_Number Year_Week    Open  \
# 0  2014-01-02  2014      1    2   Thursday            0   2014-00  183.98
# 1  2014-01-03  2014      1    3     Friday            0   2014-00  183.23
# 2  2014-01-06  2014      1    6     Monday            1   2014-01  183.49
# 3  2014-01-07  2014      1    7    Tuesday            1   2014-01  183.09
# 4  2014-01-08  2014      1    8  Wednesday            1   2014-01  183.45
#
#      High     Low   Close       Volume  Adj Close    Return    Short_MA  \
# 0  184.07  182.48  182.92  119636900.0     160.93  0.000000  160.930000
# 1  183.60  182.63  182.89   81390600.0     160.90 -0.000164  160.915000
# 2  183.56  182.08  182.36  108028200.0     160.43 -0.002898  160.753333
# 3  183.79  182.95  183.48   86144200.0     161.42  0.006142  160.920000
# 4  183.83  182.89  183.52   96582300.0     161.45  0.000218  161.026000
#
#       Long_MA  high_low_diff
# 0  160.930000           1.59
# ...

# %%
df.tail(2)
# Out:
#             Date  Year  Month  Day  Weekday  Week_Number Year_Week    Open  \
# 1508  2019-12-30  2019     12   30   Monday           52   2019-52  322.95
# 1509  2019-12-31  2019     12   31  Tuesday           52   2019-52  320.53
#
#         High     Low   Close      Volume  Adj Close    Return    Short_MA  \
# 1508  323.10  320.55  321.08  49729100.0     317.80 -0.005513  315.291429
# 1509  322.13  320.15  321.86  57077300.0     318.58  0.002429  315.989286
#
#        Long_MA  high_low_diff
# 1508  306.7830           2.55
# 1509  307.2848           1.98

# %%
df.loc[1]
# Out:
# Date             2014-01-03
# Year                   2014
# Month                     1
# Day                       3
# Weekday              Friday
# Week_Number               0
# Year_Week           2014-00
# Open                 183.23
# High                  183.6
# Low                  182.63
# Close                182.89
# Volume           81390600.0
# Adj Close             160.9
# Return            -0.000164
# Short_MA            160.915
# Long_MA             160.915
# high_low_diff          0.97
# Name: 1, dtype: object

# %%
df.iloc[3] # it’s usually better to use .iloc when your dataset doesn’t have a custom index
# Out:
# Date             2014-01-07
# Year                   2014
# Month                     1
# Day                       7
# Weekday             Tuesday
# Week_Number               1
# Year_Week           2014-01
# Open                 183.09
# High                 183.79
# Low                  182.95
# Close                183.48
# Volume           86144200.0
# Adj Close            161.42
# Return             0.006142
# Short_MA             160.92
# Long_MA              160.92
# high_low_diff          0.84
# Name: 3, dtype: object

# %%
df[["Volume", "Low"]].mean()
# Out:
# Volume    9.598298e+07
# Low       2.352877e+02
# dtype: float64

# %%
df.describe()
# Out:
#               Year        Month          Day  Week_Number         Open  \
# count  1510.000000  1510.000000  1510.000000  1510.000000  1510.000000
# mean   2016.498675     6.542384    15.747020    26.186093   236.427576
# std       1.709037     3.423962     8.747521    14.948791    37.986600
# min    2014.000000     1.000000     1.000000     0.000000   174.780000
# 25%    2015.000000     4.000000     8.000000    13.000000   204.930000
# 50%    2016.000000     7.000000    16.000000    26.000000   226.290000
# 75%    2018.000000    10.000000    23.000000    39.000000   272.142500
# max    2019.000000    12.000000    31.000000    52.000000   323.740000
#
#               High          Low        Close        Volume    Adj Close  \
# count  1510.000000  1510.000000  1510.000000  1.510000e+03  1510.000000
# mean    237.437457   235.287669   236.449219  9.598298e+07   221.643464
# std      38.071472    37.850085    37.965447  4.786140e+07    42.986136
# ...

# %%
import matplotlib.pyplot as plt
df["Return"].plot(kind='hist', bins=10, edgecolor='black', figsize=(10,6), title='Histogram of Daily Returns')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()
